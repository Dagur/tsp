# %%
import numpy
from math import sqrt

def dist(p, q):
    return sqrt(sum((px - qx) ** 2.0 for px, qx in zip(p, q)))

points = [(1, 2), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4)]

for i in range(0,len(points),2):
    (a, b) = points[i:i+2]
    print(dist(a,b))
# Out:
# 1.0
# 1.4142135623730951
# 1.0

# %%
import networkx as nx
# %matplotlib inline
import matplotlib.pyplot as plt

G = nx.Graph()
G.add_weighted_edges_from([
    (1, 2, 6), 
    (1, 3, 1),
    (1, 4, 3),
    (2, 3, 4),
    (2, 4, 3),
    (3, 4, 2)
])

#nx.draw_networkx(G, with_labels = True)
#plt.show()
elarge = [(u, v) for (u, v, d) in G.edges(data=True) if d['weight'] > 0.5]
esmall = [(u, v) for (u, v, d) in G.edges(data=True) if d['weight'] <= 0.5]

pos = nx.spring_layout(G, center=(1,1), weight=10)  # positions for all nodes
print(pos)

nx.draw_networkx_nodes(G, pos, node_size=700)

nx.draw_networkx_edges(G, pos, edgelist=elarge,
                       width=6)
nx.draw_networkx_edges(G, pos, edgelist=esmall,
                       width=6, alpha=0.5, edge_color='b', style='dashed')

nx.draw_networkx_labels(G, pos, font_size=20, font_family='sans-serif')
    
plt.show()
# Out:
# {1: array([0.95473014, 2.        ]), 2: array([5.36039300e-04, 9.54754404e-01]), 3: array([1.99946396, 1.0452456 ]), 4: array([1.04526986, 0.        ])}

# %%
matrix = nx.to_numpy_matrix(G)
m = matrix.A
m[0].size

bla = set([1,2,3])
bla.difference([2])
# Out:
# {1, 3}
